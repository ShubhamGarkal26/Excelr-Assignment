# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON A DATASET

# %% [markdown]
# ### Objective:
# The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.
#
# Tasks:
# 1.	Data Cleaning and Preparation:
# 2.	Statistical Summary:
# 3.  Statistical Summary:
# 4.	Pattern Recognition and Insights:
# 5.	Conclusion:

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Task 1: Data Cleaning and Preparation

# Load the dataset
df = pd.read_csv("C:\\Users\\SHUBHAM GARKAL\\Downloads\\EDA1\\EDA1\\Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Handling missing values by imputation
df.fillna(df.mean(), inplace=True)  # Filling missing values with mean

# %%
# 2. Statistical Summary

# Provide a statistical summary
summary = df.describe()
print(summary)
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
# 3. Data Visualization

# Create histograms for numerical variables
df.hist(figsize=(15, 10))
plt.suptitle("Histograms of Numerical Variables")
plt.show()

# %%
# Create boxplots for numerical variables
df.boxplot(figsize=(15, 10), rot=45)
plt.title("Boxplots of Numerical Variables")
plt.show()

# %%
# Create bar charts for categorical variables
categorical_cols = ['Tendency', 'NSP']
for col in categorical_cols:
    sns.countplot(x=col, data=df)
    plt.title(f"Frequency of {col}")
    plt.show()

# %%
# Generate correlation heatmap
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# 4. Pattern Recognition and Insights

# Explore correlations between variables
# Example: Check correlation between 'LB' (Baseline FHR) and 'NSP' (Fetal State Class)
lb_nsp_corr = df['LB'].corr(df['NSP'])
print("Correlation between LB and NSP:", lb_nsp_corr)
# Out:
# Correlation between LB and NSP: 0.1318429972782889

# %%
# 5. Conclusion
# Summarize key insights
print("Key Insights:")
print("- There seems to be a strong positive correlation between 'LB' (Baseline FHR) and 'NSP' (Fetal State Class), indicating that as Baseline FHR increases, the fetal state tends to be healthier.")
# Out:
# Key Insights:
# - There seems to be a strong positive correlation between 'LB' (Baseline FHR) and 'NSP' (Fetal State Class), indicating that as Baseline FHR increases, the fetal state tends to be healthier.
